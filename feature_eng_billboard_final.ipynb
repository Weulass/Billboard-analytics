# %%
#Python libraries we may need
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from datetime import timedelta
import numpy as np

# %%
#upload the original database df
with open('hot-100_data.pkl', 'rb') as f:
        df = pickle.load(f)

# %%
#we check the database
df
# Out:
#                                artist                                  title  \
# 0                       Lewis Capaldi                      Someone You Loved
# 1                         Post Malone                                Circles
# 2       Shawn Mendes & Camila Cabello                               Senorita
# 3                               Lizzo                            Truth Hurts
# 4                        Selena Gomez                    Lose You To Love Me
# ...                               ...                                    ...
# 113195                        Rockell                             In A Dream
# 113196              Daryle Singletary                               The Note
# 113197                    Kim Sanders                               Jealousy
# 113198                   Shania Twain  Don't Be Stupid (You Know I Love You)
# 113199                  Reba McEntire                                What If
#
#         isnew rank        date
# ...

# %%
# add features numberofappearances, best rank and first rank for each song
#we also count the number of songs each artist placed on the Hot 100 and Hot 10 before releasing the song 
df["numberofappearances"]=0
df["bestrank"]=0
df["firstrank"]=0
df["numberofappearances_artist"]=0
df["numberofappearances_artist_top10"]=0
for i in range(len(df)):
    title=df.title.loc[i]
    artist=df.artist.loc[i]
    date=df.date.loc[i]
    new_df=df[df["artist"] == artist][df["title"] == title][df["date"] <= date]
    table=new_df[new_df.artist==artist]
    table=table[table.title==title]
    df["numberofappearances"].loc[i]=len(table)
    df["bestrank"].loc[i]=table["rank"].min()
    df["firstrank"].loc[i]=table["rank"].iloc[-1]
    df["numberofappearances_artist"].loc[i]=len(df[df["artist"] == artist][df["title"] != title][df["date"] <= date].title.unique())
    df["numberofappearances_artist_top10"].loc[i]=len(df[df["artist"] == artist][df["title"] != title][df["date"] <= date][df["rank"]<11].title.unique())
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
#creation of new_df, which aggregates df by artist

artists=df.artist.unique()
nb_songs=[]
new_df=pd.DataFrame()
new_df["artist"]=artists
for i in range(len(artists)):
    songs=len(df[df.artist==artists[i]].title.unique())
    nb_songs.append(songs)

# %%
new_df["numberofsongs"]=nb_songs

# %%
#number of top 10 reached by each artist

top=[]
for i in range(len(artists)):
    top_10=0
    song=df[df.artist==artists[i]].title.unique()
    for i in range(len(song)):
        if df[df.title==song[i]].bestrank.min() < 11:
            top_10=top_10+1
    top.append(top_10)

# %%
#Best rank ever reached by each artist

bestrank=[]
for i in range(len(artists)):
    rank=df[df.artist==artists[i]].bestrank.min()
    bestrank.append(rank)
new_df["bestrankever"]=bestrank

# %%
#number of top 50 reached by each artist

top_50=[]
for i in range(len(artists)):
    top=0
    song=df[df.artist==artists[i]].title.unique()
    for i in range(len(song)):
        if df[df.title==song[i]].bestrank.min() < 51:
            top=top+1
    top_50.append(top)
new_df["numberoftop50"]=top_50

# %%
#number of top 75 reached by each artist

top_75=[]
for i in range(len(artists)):
    top=0
    song=df[df.artist==artists[i]].title.unique()
    for i in range(len(song)):
        if df[df.title==song[i]].bestrank.min() < 76:
            top=top+1
    top_75.append(top)
new_df["numberoftop75"]=top_75

# %%
#number of top 25 reached by each artist

top_25=[]
for i in range(len(artists)):
    top=0
    song=df[df.artist==artists[i]].title.unique()
    for i in range(len(song)):
        if df[df.title==song[i]].bestrank.min() < 26:
            top=top+1
    top_25.append(top)
new_df["numberoftop25"]=top_25

# %%
#number of weeks with at least one song in the Billboard Top 100

weeks=[]
for i in range(len(artists)):
    week=0
    week=len(df[df.artist==artists[i]].date.unique())
    weeks.append(week)
new_df["numberofweeks"]=weeks

# %%
new_df
# Out:
#                                       artist  numberofsongs  numberoftop10  \
# 0                              Lewis Capaldi              1              1
# 1                                Post Malone             26              4
# 2              Shawn Mendes & Camila Cabello              2              1
# 3                                      Lizzo              3              2
# 4                               Selena Gomez             12              7
# ...                                      ...            ...            ...
# 3925                     Fruit De La Passion              1              0
# 3926  Mic Geronimo Featuring DMX & Black Rob              1              0
# 3927              Richard Marx & Donna Lewis              1              0
# 3928                                  Phajja              1              0
# 3929                      Sting & The Police              1              0
#
# ...

# %%
#to clean our dataset, we compute the median time for a song to reach the top 10 

datetimeFormat = '%Y-%m-%d'
times=[]
top10=df[df["rank"]<11]
artists_top10=top10.artist.unique()
for artist in artists_top10:
    titles_top10=top10[times_top10["artist"]==artist].title.unique()
    for title in titles_top10:
        date1=df[df.title==title][df["artist"]==artist][df["rank"]<11].date.min()
        date2=df[df.title==title][df["artist"]==artist].date.min()
        diff=date1-date2
        diff= diff.days
        times.append(diff)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
avg_time_to_top10=np.median(times)/7 #6 weeks!

# %%
df[df["artist"]=="Post Malone"]
# Out:
#             artist          title  isnew rank        date  \
# 1      Post Malone        Circles  False    2  2019-11-16
# 102    Post Malone        Circles  False    3  2019-11-09
# 203    Post Malone        Circles  False    4  2019-11-02
# 245    Post Malone           Wow.  False   46  2019-11-02
# 303    Post Malone        Circles  False    4  2019-10-26
# ...            ...            ...    ...  ...         ...
# 21352  Post Malone  White Iverson  False   53  2015-10-24
# 21467  Post Malone  White Iverson  False   68  2015-10-17
# 21572  Post Malone  White Iverson  False   73  2015-10-10
# 21670  Post Malone  White Iverson  False   71  2015-10-03
# 21783  Post Malone  White Iverson   True   84  2015-09-26
#
#        numberofappearances  bestrank  firstrank  numberofappearances_artist  \
# 1                       10         2          7                          25
# 102                      9         3          7                          25
# ...
